# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('../DataSets/weatherAUS.csv')
X = pd.read_csv('../DataSets/weatherAUS.csv')
X.pop('Date')
Y = X.pop('RainTomorrow')
Y = pd.DataFrame(Y)
X
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury     13.4     22.9       0.6          NaN       NaN
# 1        Albury      7.4     25.1       0.0          NaN       NaN
# 2        Albury     12.9     25.7       0.0          NaN       NaN
# 3        Albury      9.2     28.0       0.0          NaN       NaN
# 4        Albury     17.5     32.3       1.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 145455    Uluru      2.8     23.4       0.0          NaN       NaN
# 145456    Uluru      3.6     25.3       0.0          NaN       NaN
# 145457    Uluru      5.4     26.9       0.0          NaN       NaN
# 145458    Uluru      7.8     27.0       0.0          NaN       NaN
# 145459    Uluru     14.9      NaN       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  WindSpeed3pm  \
# 0                W           44.0          W        WNW  ...          24.0
# ...

# %%
import helper as hp
preprocessor = preProcessing(X)

# %%
raintom_vals = {'No': 0, 'Yes': 1}
df['RainTomorrow'] = df.RainTomorrow.map(raintom_vals)

# %%
numeric_cols = preprocessor.dtype_select(np.number)
numeric_cols
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm']

# %%
cat_cols = preprocessor.dtype_select('object')
cat_cols
# Out:
# ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday']

# %%
X[cat_cols].fillna("Unknown")
X[cat_cols].head(20)
# Out:
#    Location WindGustDir WindDir9am WindDir3pm RainToday
# 0    Albury           W          W        WNW        No
# 1    Albury         WNW        NNW        WSW        No
# 2    Albury         WSW          W        WSW        No
# 3    Albury          NE         SE          E        No
# 4    Albury           W        ENE         NW        No
# 5    Albury         WNW          W          W        No
# 6    Albury           W         SW          W        No
# 7    Albury           W        SSE          W        No
# 8    Albury         NNW         SE         NW        No
# 9    Albury           W          S        SSE       Yes
# 10   Albury           N        SSE        ESE        No
# 11   Albury         NNE         NE        ENE       Yes
# 12   Albury           W        NNW        NNW       Yes
# 13   Albury          SW          W        SSW       Yes
# 14   Albury         NaN          S        WNW        No
# 15   Albury         WNW        NaN        WNW       NaN
# ...

# %%
X[numeric_cols] = preprocessor.impute(numeric_cols=numeric_cols)
X[numeric_cols]
# Out:
#         MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4  22.900000       0.6     5.468232  7.611178       44.00000
# 1           7.4  25.100000       0.0     5.468232  7.611178       44.00000
# 2          12.9  25.700000       0.0     5.468232  7.611178       46.00000
# 3           9.2  28.000000       0.0     5.468232  7.611178       24.00000
# 4          17.5  32.300000       1.0     5.468232  7.611178       41.00000
# ...         ...        ...       ...          ...       ...            ...
# 145455      2.8  23.400000       0.0     5.468232  7.611178       31.00000
# 145456      3.6  25.300000       0.0     5.468232  7.611178       22.00000
# 145457      5.4  26.900000       0.0     5.468232  7.611178       37.00000
# 145458      7.8  27.000000       0.0     5.468232  7.611178       28.00000
# 145459     14.9  23.221348       0.0     5.468232  7.611178       40.03523
#
# ...

# %%
X[numeric_cols] = preprocessor.minMax(numeric_cols=numeric_cols)
X[numeric_cols].describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  145460.000000  145460.000000  145460.000000  145460.000000
# mean        0.488067       0.529704       0.006364       0.037712
# std         0.150136       0.133991       0.022594       0.021804
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.382075       0.431002       0.000000       0.027586
# 50%         0.485849       0.519849       0.000000       0.037712
# 75%         0.596698       0.623819       0.002695       0.037712
# max         1.000000       1.000000       1.000000       1.000000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  145460.000000  145460.000000  145460.000000  145460.000000
# mean        0.524909       0.263839       0.108026       0.214513
# std         0.188240       0.101692       0.068162       0.100191
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
X
# Out:
#        Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury  0.516509  0.523629  0.001617     0.037712  0.524909
# 1        Albury  0.375000  0.565217  0.000000     0.037712  0.524909
# 2        Albury  0.504717  0.576560  0.000000     0.037712  0.524909
# 3        Albury  0.417453  0.620038  0.000000     0.037712  0.524909
# 4        Albury  0.613208  0.701323  0.002695     0.037712  0.524909
# ...         ...       ...       ...       ...          ...       ...
# 145455    Uluru  0.266509  0.533081  0.000000     0.037712  0.524909
# 145456    Uluru  0.285377  0.568998  0.000000     0.037712  0.524909
# 145457    Uluru  0.327830  0.599244  0.000000     0.037712  0.524909
# 145458    Uluru  0.384434  0.601134  0.000000     0.037712  0.524909
# 145459    Uluru  0.551887  0.529704  0.000000     0.037712  0.524909
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  WindSpeed3pm  \
# ...

# %%
missing_counts = X.isna().sum().sort_values(ascending=False)
missing_counts[missing_counts > 0]
# Out:
# WindDir9am     10566
# WindGustDir    10326
# WindDir3pm      4228
# RainToday       3261
# dtype: int64

# %%
X[cat_cols] = preprocessor.one_hot(cat_cols=cat_cols)
for col in cat_cols:
    X.pop(col)
# Out:
# /Users/anshumantekriwal/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /var/folders/37/cr55t1yj4_q7mn_gwsg1qk640000gn/T/ipykernel_95332/787974572.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.df[encoded_cols] = enc.transform(self.df[cat_cols])
# ...

# %%
print(Y.isna().sum())
Y = Y.replace(np.nan, 'No')
Y.isna().sum()
# Out:
# RainTomorrow    3267
# dtype: int64
# RainTomorrow    0
# dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='liblinear')
model.fit(X, Y)
# Out:
# /Users/anshumantekriwal/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(solver='liblinear')
